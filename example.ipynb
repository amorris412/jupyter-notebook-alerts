# %% [markdown]
# # Test Notebook Alert
#
# This notebook demonstrates the desktop alert system.
#
# Run all cells to see a **green flashing alert** when complete!

# %%
# Simple test calculation
import time

print("Starting test calculation...")
time.sleep(2)  # Simulate some work

result = sum(range(1000))
print(f"Result: {result}")
print("Calculation complete!")

# %%
# Trigger success alert!
from notebook_auto_alert import done
done("Test notebook completed successfully!")
